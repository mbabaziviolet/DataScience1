# %% [markdown]
# # Importing libraries and dependences

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Importing Data Set

# %%
df = pd.read_excel(r'C:\Users\mbabazi\Desktop\DataScience1\Goalfinal1000.xlsx')

# %%
df.head()
# Out:
#        Applicant Name  Gender      Contact Business Name/Identification  \
# 0      Aballa Vincent    Male    789600088   Akison General enterprises
# 1  Abang Gloria faith  Female    774630754             Produce Business
# 2    Okeno David (24)    Male    772421851                  Sells peas
# 3  Aber Innocent Mark    Male  784 763 815                      Piggery
# 4          Abuo Dinah  Female    781575295   Cash crop farming/ pottery
#
#   District Sub-County  \
# 0     Abim     Alerek
# 1     Lira     Ojwina
# 2     Lira       Ogur
# 3     Lira     Ngetta
# 4     Abim    Molulem
#
#   Merchandise Dealing in (Products) - List them all as per the respondent  \
# 0                                       Wine & beer
# 1                  maize, beans, rice, soya, sim sim
# 2                                               Peas
# 3                                            piggery
# 4                                            pottery
#
# ...

# %%
import pandas as pd
goal = pd.read_excel(r'C:\Users\mbabazi\Desktop\DataScience1\Goalfinal1000_1.xlsx')
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
olympics = pd.read_excel(r'C:\Users\mbabazi\Desktop\DataScience1\olympics.xlsx')
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
#the olympics dataframe
import pandas as pd
oo = pd.read_excel(r"C:\Users\mbabazi\Desktop\DataScience1\olympics.xlsx")
oo
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
#the country code
oo['Country_Code']
# Out:
# 0        GDR
# 1        URS
# 2        USA
# 3        ITA
# 4        USA
#         ...
# 15428    FRA
# 15429    GEO
# 15430    AZE
# 15431    FRA
# 15432    CUB
# Name: Country_Code, Length: 15433, dtype: object

# %%
#type method
type(oo.Athlete) #oo represents my dataframe
# Out:
# pandas.core.series.Series

# %%
#dot notation 
(oo.Athlete)
#this method for dot notation works out wen the seriesname eg Athlete has no spaces
# Out:
# 0                 KÖHLER, Christa
# 1             KOSENKOV, Aleksandr
# 2            BOGGS, Philip George
# 3        CAGNOTTO, Giorgio Franco
# 4          WILSON, Deborah Keplar
#                    ...
# 15428          GUENOT, Christophe
# 15429         KVIRKELIA, Manuchar
# 15430            RAHIMOV, Vitaliy
# 15431              GUENOT, Steeve
# 15432               LOPEZ, Mijain
# Name: Athlete, Length: 15433, dtype: object

# %%
#dot notation
(oo.Country_Code)
# Out:
# 0        GDR
# 1        URS
# 2        USA
# 3        ITA
# 4        USA
#         ...
# 15428    FRA
# 15429    GEO
# 15430    AZE
# 15431    FRA
# 15432    CUB
# Name: Country_Code, Length: 15433, dtype: object

# %%
type(oo['Country_Code']) #[''] method type
# Out:
# pandas.core.series.Series

# %%
#the list of Sport,City,Athletics Name,Medal columns
oo[['Sport','City','Athlete','Medal']]
# Out:
#            Sport      City                   Athlete   Medal
# 0       Aquatics  Montreal           KÖHLER, Christa  Silver
# 1       Aquatics  Montreal       KOSENKOV, Aleksandr  Bronze
# 2       Aquatics  Montreal      BOGGS, Philip George    Gold
# 3       Aquatics  Montreal  CAGNOTTO, Giorgio Franco  Silver
# 4       Aquatics  Montreal    WILSON, Deborah Keplar  Bronze
# ...          ...       ...                       ...     ...
# 15428  Wrestling   Beijing        GUENOT, Christophe  Bronze
# 15429  Wrestling   Beijing       KVIRKELIA, Manuchar    Gold
# 15430  Wrestling   Beijing          RAHIMOV, Vitaliy  Silver
# 15431  Wrestling   Beijing            GUENOT, Steeve    Gold
# 15432  Wrestling   Beijing             LOPEZ, Mijain    Gold
#
# [15433 rows x 4 columns]

# %%
type(oo['Sport','City','Athlete','Medal']) #[''] method object type

# %%
#jesse
oo[['Athlete','Medal','Sport']]
oo.loc[(oo.Athlete=='Jesse Owens')&(oo.Medal=='Gold')&(oo.Sport=='Aquatics')]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Event, Athlete, Gender, Country_Code, Country, Event_gender, Medal]
# Index: []

# %%
#the country which has won most gold medals
oo[(oo.Medal=='Gold')&(oo.Gender=='Men')&(oo.Discipline=='Swimming')],oo.Athlete.value_counts()
#value_counts returns the series object counting all unique values , usually the first value is the most occuring value
# Out:
# (           City    Year     Sport Discipline                   Event  \
#  22     Montreal  1976.0  Aquatics   Swimming          400m freestyle
#  26     Montreal  1976.0  Aquatics   Swimming          100m butterfly
#  28     Montreal  1976.0  Aquatics   Swimming         100m backstroke
#  33     Montreal  1976.0  Aquatics   Swimming  4x200m freestyle relay
#  42     Montreal  1976.0  Aquatics   Swimming  4x200m freestyle relay
#  ...         ...     ...       ...        ...                     ...
#  13577   Beijing  2008.0  Aquatics   Swimming           50m freestyle
#  13593   Beijing  2008.0  Aquatics   Swimming  4x100m freestyle relay
#  13594   Beijing  2008.0  Aquatics   Swimming       200m breaststroke
#  13597   Beijing  2008.0  Aquatics   Swimming  200m individual medley
#  13625   Beijing  2008.0  Aquatics   Swimming  4x100m freestyle relay
#
#                        Athlete Gender Country_Code        Country Event_gender  \
# ...

# %%
#three countries
#oo.Country.value_counts() will output Us as the most occuring
oo[['Medal','Year','Country']]
oo = oo[['Medal','Year','Country']]
oo
# Out:
#         Medal    Year        Country
# 0      Silver  1976.0   East Germany
# 1      Bronze  1976.0   Soviet Union
# 2        Gold  1976.0  United States
# 3      Silver  1976.0          Italy
# 4      Bronze  1976.0  United States
# ...       ...     ...            ...
# 15428  Bronze  2008.0         France
# 15429    Gold  2008.0        Georgia
# 15430  Silver  2008.0     Azerbaijan
# 15431    Gold  2008.0         France
# 15432    Gold  2008.0           Cuba
#
# [15433 rows x 3 columns]

# %%
#male gold medal winners
oo[(oo.Medal=='Gold')&(oo.Event_gender=='M')&(oo.Event=='100m')]
# Out:
#               City    Year      Sport Discipline Event            Athlete  \
# 308       Montreal  1976.0  Athletics  Athletics  100m   CRAWFORD, Hasely
# 1657        Moscow  1980.0  Athletics  Athletics  100m       WELLS, Allan
# 3052   Los Angeles  1984.0  Athletics  Athletics  100m        LEWIS, Carl
# 4587         Seoul  1988.0  Athletics  Athletics  100m        LEWIS, Carl
# 6198     Barcelona  1992.0  Athletics  Athletics  100m  CHRISTIE, Linford
# 7881       Atlanta  1996.0  Athletics  Athletics  100m    BAILEY, Donovan
# 9850        Sydney  2000.0  Athletics  Athletics  100m    GREENE, Maurice
# 11901       Athens  2004.0  Athletics  Athletics  100m     GATLIN, Justin
# 13839      Beijing  2008.0  Athletics  Athletics  100m        BOLT, Usain
#
#       Gender Country_Code              Country Event_gender Medal
# 308      Men          TRI  Trinidad and Tobago            M  Gold
# 1657     Men          GBR       United Kingdom            M  Gold
# ...

# %%
#example for silver ,returns columns where an athlete won silver medal
oo.Medal=='Silver'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 15428    False
# 15429    False
# 15430     True
# 15431    False
# 15432    False
# Name: Medal, Length: 15433, dtype: bool

# %%
#example where an athlete won only silver medals
oo[oo.Medal =='Silver']
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 5      Montreal  1976.0   Aquatics           Diving    10m platform
# 10     Montreal  1976.0   Aquatics           Diving    10m platform
# 13     Montreal  1976.0   Aquatics         Swimming  400m freestyle
# ...         ...     ...        ...              ...             ...
# 15416   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15419   Beijing  2008.0  Wrestling  Wrestling Gre-R       74 - 84kg
# 15426   Beijing  2008.0  Wrestling  Wrestling Gre-R       84 - 96kg
# 15427   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
#plotting using matplot and seaborn
import seaborn as sns
#qn1
#number of medals achieved by chiniz team in Beijing in 2008
oo = oo[(oo.City == "Beijing") & (oo.Year == 2008)]
oo

# %%
oo[(oo.City == "Beijing") & (oo.Year == 2008)],oo.Medal.value_counts()
# Out:
# (          City    Year      Sport       Discipline  \
#  13391  Beijing  2008.0   Aquatics           Diving
#  13392  Beijing  2008.0   Aquatics           Diving
#  13393  Beijing  2008.0   Aquatics           Diving
#  13394  Beijing  2008.0   Aquatics           Diving
#  13395  Beijing  2008.0   Aquatics           Diving
#  ...        ...     ...        ...              ...
#  15428  Beijing  2008.0  Wrestling  Wrestling Gre-R
#  15429  Beijing  2008.0  Wrestling  Wrestling Gre-R
#  15430  Beijing  2008.0  Wrestling  Wrestling Gre-R
#  15431  Beijing  2008.0  Wrestling  Wrestling Gre-R
#  15432  Beijing  2008.0  Wrestling  Wrestling Gre-R
#
#                                      Event              Athlete Gender  \
#  13391                      3m springboard             QIN, Kai    Men
#  13392    synchronized diving 10m platform             LIN, Yue    Men
#  13393    synchronized diving 10m platform          WU, Melissa  Women
# ...

# %%
#plotting qn1
#oo.value_counts() will bring the most occurring eg bronze has 700
oo.Medal.value_counts().plot(kind = 'bar')

# %%
#using pie chart
oo.Medal.value_counts().plot(kind = 'pie')

# %%
#qn2
#how color maps are used to give data more meaning
The color maps control the way data is understood when plotted because they map data values to color

# %%
#qn3
#plotting number of gold,silver,bronze for each gender
oo[['Medal','Gender']]
oo.Medal.value_counts().plot(kind = 'bar'),oo.Gender.value_counts().plot(kind ='bar')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x12dfc25a6c8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12dfc25a6c8>)

# %%
import pandas as pd
oo = pd.read_excel(r'C:\Users\mbabazi\Desktop\DataScience1\olympics.xlsx')
oo
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
import seaborn as sns
sns.countplot(x = 'Medal', data=oo , hue='Gender');

# %%
sns.countplot(x = 'Sport', data=oo , hue='Gender');

# %%
#qn4
#how to give data more meaning
I can make it myself, experiment it and measure something like my house.It also helps me to figure out questions I would prefer to ask.

# %%
import pandas as pd
purchases=pd.read_json(r'C:\Users\mbabazi\Desktop\DataScience1\purchases.json')
purchases.head()
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#organising as a dictionary
data = {
    'apples':[3,2,0,1],
    'oranges':[0,3,7,2]
    
}
purchases=pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases=pd.read_csv(r'C:\Users\mbabazi\Desktop\DataScience1\purchases.csv')
purchases.head()
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
#making it a dictionary
fruits={
    'Unnamed': ['June','Robert','Lily','David'],
    'apples': [3,2,0,1],
    'oranges': [0,3,7,2]
}
purchases=pd.DataFrame(fruits)
purchases
# Out:
#   Unnamed  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
purchases=pd.DataFrame(fruits,index=['June','Robert','Lily','David'])
purchases
# Out:
#        Unnamed  apples  oranges
# June      June       3        0
# Robert  Robert       2        3
# Lily      Lily       0        7
# David    David       1        2

# %%
#locate customers name by index
purchases.loc['Robert']
# Out:
# Unnamed    Robert
# apples          2
# oranges         3
# Name: Robert, dtype: object

# %%
#load the dataframe using csv files
df = pd.read_csv('purchases.csv')
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2
